# %% [markdown]
# # Little Women  Book Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from gensim.models import Word2Vec

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["figure.figsize"] = (7,4)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Word_embedding
#
# Word embedding, bir kelime veya ifade için düz bir vektör olarak ifade edilmesidir. Bu vektörler, kelimelerin anlamları arasındaki benzerlikleri yansıtmak üzere öğrenilir. Bu sayede, yapay zeka modelleri kelimeler arasındaki ilişkileri daha iyi anlayabilir
#
# Word embedding, metin verileri kullanılarak öğrenilir. Örneğin, bir metin corpus'u (büyük metin veritabanı) kullanılarak, her kelime için çevresindeki kelimeler ile ilişkisini öğrenir. Bu ilişki, kelime ve çevresindeki kelimeler arasındaki co-occurrence (ortak görünüm) frekansı olarak tanımlanır. Daha sonra, bu co-occurrence verileri kullanarak, her kelime için bir vektör oluşturulur. Bu vektörler, kelimelerin anlamları arasındaki benzerlikleri yansıtmak üzere tasarlanır.
#
# Örneğin, "king" ve "queen" kelimeleri sıklıkla aynı metinlerde görülür ve benzer anlamlar taşır, bu nedenle oluşan vektörleri birbirine yakın olacak. Ancak "king" ve "orange" kelimeleri sıklıkla aynı metinlerde görülmez ve farklı anlamlar taşır, bu nedenle oluşan vektörleri birbirinden uzak olacak.

# %% [markdown]
# ## we will learn about our book

# %%
df = pd.read_csv('37106.zip', sep='\t',
                  lineterminator='\r',
                  error_bad_lines=False,names = ["sentence"])
df
# Out:
#                                                 sentence
# 0      The Project Gutenberg EBook of Little Women, b...
# 1                                                     \n
# 2      \nThis eBook is for the use of anyone anywhere...
# 3      \nalmost no restrictions whatsoever.  You may ...
# 4      \nre-use it under the terms of the Project Gut...
# ...                                                  ...
# 22865                                                 \n
# 22866  \nThis Web site includes information about Pro...
# 22867  \nincluding how to make donations to the Proje...
# 22868  \nArchive Foundation, how to help produce our ...
# 22869  \nsubscribe to our email newsletter to hear ab...
#
# [22870 rows x 1 columns]

# %%
df.shape
# Out:
# (22870, 1)

# %%
df.sentence[15]
# Out:
# '\nRelease Date: August 16, 2011 [EBook #37106]'

# %%
df.isnull().sum()
# Out:
# sentence    0
# dtype: int64

# %%
df.nunique()
# Out:
# sentence    17711
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 5159

# %% [markdown]
# ## 3. Text Mining
#
# Text is the most unstructured form of all the available data, therefore various types of noise are present in it. This means that the data is not readily analyzable without any pre-processing. The entire process of cleaning and standardization of text, making it noise-free and ready for analysis is known as **text preprocessing**.
#
# The three key steps of text preprocessing:
#
# - **Tokenization:**
# This step is one of the top priorities when it comes to working on text mining. Tokenization is essentially splitting a phrase, sentence, paragraph, or an entire text document into smaller units, such as individual words or terms. Each of these smaller units are called tokens.
#
# - **Noise Removal:**
# Any piece of text which is not relevant to the context of the data and the end-output can be specified as the noise.
# For example – language stopwords (commonly used words of a language – is, am, the, of, in etc), URLs or links, upper and lower case differentiation, punctuations and industry specific words. This step deals with removal of all types of noisy entities present in the text.
#
#
# - **Lexicon Normalization:**
# Another type of textual noise is about the multiple representations exhibited by single word.
# For example – “play”, “player”, “played”, “plays” and “playing” are the different variations of the word – “play”. Though they mean different things, contextually they all are similar. This step converts all the disparities of a word into their normalized form (also known as lemma).
# There are two methods of lexicon normalisation; **[Stemming or Lemmatization](https://www.guru99.com/stemming-lemmatization-python-nltk.html)**. Lemmatization is recommended for this case, because Lemmatization as this will return the root form of each word (rather than just stripping suffixes, which is stemming).
#
# As the first step change text to tokens and convertion all of the words to lower case.  Next remove punctuation, bad characters, numbers and stop words. The second step is aimed to normalization them throught the Lemmatization method.
#
#
# ***Note:*** *Use the functions of the ***[nltk Library](https://www.guru99.com/nltk-tutorial.html)*** for all the above operations.*

# %%
stop_words = stopwords.words('english')

# %%
def cleaning(data):
    
    #1. Tokenize and lower
    text_tokens = word_tokenize(data.lower()) 
    
    #2. Remove Puncs and numbers
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]
    
    #3. Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    
    #4. lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]
    
    #5. joining
    return " ".join(text_cleaned)

# %%
def cleaning(data):
    
    import re
    
    #1. Removing URLS
    data = re.sub('http\S*', '', data).strip()
    data = re.sub('www\S*', '', data).strip()

    #2. Removing Tags
    data = re.sub('#\S*', '', data).strip()

    #3. Removing Mentions
    data = re.sub('@\S*', '', data).strip()
    
    #4. Removing upper brackets to keep negative auxiliary verbs in text
    data = data.replace("'", "")
    
    #5. Tokenize
    text_tokens = word_tokenize(data.lower())
    
    #6. Remove Puncs and numbers
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]
    
    #7. Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    
    #8. lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]
    
       
    #9. joining
    return " ".join( text_cleaned)

# %%
df2 = df.copy()

# %%
df2["sentence"] = df["sentence"].apply(cleaning)
df2["sentence"].head()
# Out:
# 0    project gutenberg ebook little woman louisa al...
# 1
# 2                       ebook use anyone anywhere cost
# 3     almost restriction whatsoever may copy give away
# 4              term project gutenberg license included
# Name: sentence, dtype: object

# %%
df2.sentence[1]
# Out:
# ''

# %%
" ".join(df2["sentence"]).split()
# Out:
# ['project',
#  'gutenberg',
#  'ebook',
#  'little',
#  'woman',
#  'louisa',
#  'alcott',
#  'ebook',
#  'use',
#  'anyone',
#  'anywhere',
#  'cost',
#  'almost',
#  'restriction',
#  'whatsoever',
#  'may',
#  'copy',
#  'give',
#  'away',
#  'term',
#  'project',
#  'gutenberg',
#  'license',
#  'included',
#  'ebook',
#  'online',
#  'title',
#  'little',
#  'woman',
#  'meg',
#  'jo',
#  'beth',
#  'amy',
#  'author',
#  'louisa',
#  'alcott',
#  'illustrator',
#  'frank',
#  'merrill',
#  'release',
#  'date',
#  'august',
#  'ebook',
#  'last',
#  'update',
#  'august',
#  'language',
#  'english',
#  'start',
#  'project',
#  'gutenberg',
#  'ebook',
#  'little',
#  'woman',
#  'produced',
#  'david',
#  'edward',
#  'ernest',
#  'schaal',
#  'robert',
#  'homa',
#  'online',
#  'distributed',
#  'proofreading',
#  'team',
#  'http',
#  'file',
#  'produced',
#  'image',
#  'generously',
#  'made',
#  'available',
#  'internet',
#  'archive',
#  'illustration',
#  'little',
#  'woman',
#  'meg',
#  'jo',
#  'beth',
#  'amy',
#  'louisa',
#  'alcott',
#  'little',
#  'woman',
#  'illustration',
#  'drew',
#  'fire',
#  'mother',
#  'big',
#  'chair',
#  'beth',
#  'foot',
#  'see',
#  'page',
#  'frontispiece',
#  'little',
#  'woman',
#  'meg',
#  'jo',
#  'beth',
#  'amy',
#  'louisa',
#  'alcott',
#  'author',
#  'little',
#  'men',
#  'girl',
#  'story',
#  'etc',
#  'illustration',
#  'frank',
#  'merrill',
#  'picture',
#  'home',
#  'little',
#  'woman',
#  'edmund',
#  'boston',
#  'little',
#  'brown',
#  'company',
#  'entered',
#  'according',
#  'act',
#  'congress',
#  'year',
#  'louisa',
#  'alcott',
#  'clerk',
#  'office',
#  'district',
#  'court',
#  'district',
#  'massachusetts',
#  'louisa',
#  'alcott',
#  'john',
#  'alcott',
#  'boston',
#  'alfred',
#  'mudge',
#  'son',
#  'printer',
#  'illustration',
#  'preface',
#  'little',
#  'book',
#  'show',
#  'entertain',
#  'bid',
#  'thee',
#  'welcome',
#  'shall',
#  'thou',
#  'dost',
#  'keep',
#  'close',
#  'shut',
#  'thy',
#  'breast',
#  'wish',
#  'thou',
#  'dost',
#  'show',
#  'may',
#  'blest',
#  'good',
#  'may',
#  'make',
#  'choose',
#  'pilgrim',
#  'better',
#  'far',
#  'thee',
#  'tell',
#  'mercy',
#  'one',
#  'early',
#  'hath',
#  'pilgrimage',
#  'begun',
#  'yea',
#  'let',
#  'young',
#  'damsel',
#  'learn',
#  'prize',
#  'world',
#  'come',
#  'wise',
#  'little',
#  'tripping',
#  'maid',
#  'may',
#  'follow',
#  'god',
#  'along',
#  'way',
#  'saintly',
#  'foot',
#  'adapted',
#  'john',
#  'bunyan',
#  'illustration',
#  'content',
#  'part',
#  'first',
#  'chapter',
#  'page',
#  'playing',
#  'pilgrim',
#  'ii',
#  'merry',
#  'christmas',
#  'iii',
#  'laurence',
#  'boy',
#  'iv',
#  'burden',
#  'neighborly',
#  'vi',
#  'beth',
#  'find',
#  'palace',
#  'beautiful',
#  'vii',
#  'amy',
#  'valley',
#  'humiliation',
#  'viii',
#  'jo',
#  'meet',
#  'apollyon',
#  'ix',
#  'meg',
#  'go',
#  'vanity',
#  'fair',
#  'xi',
#  'experiment',
#  'xii',
#  'camp',
#  'laurence',
#  'xiii',
#  'castle',
#  'air',
#  'xiv',
#  'secret',
#  'xv',
#  'telegram',
#  'xvi',
#  'letter',
#  'xvii',
#  'little',
#  'faithful',
#  'xviii',
#  'dark',
#  'day',
#  'xix',
#  'amy',
#  'xx',
#  'confidential',
#  'xxi',
#  'laurie',
#  'make',
#  'mischief',
#  'jo',
#  'make',
#  'peace',
#  'xxii',
#  'pleasant',
#  'meadow',
#  'xxiii',
#  'aunt',
#  'march',
#  'settle',
#  'question',
#  'part',
#  'second',
#  'xxiv',
#  'gossip',
#  'xxv',
#  'first',
#  'wedding',
#  'xxvi',
#  'artistic',
#  'attempt',
#  'xxvii',
#  'literary',
#  'lesson',
#  'xxviii',
#  'domestic',
#  'experience',
#  'xxix',
#  'call',
#  'xxx',
#  'consequence',
#  'xxxi',
#  'foreign',
#  'correspondent',
#  'xxxii',
#  'tender',
#  'trouble',
#  'xxxiii',
#  'jo',
#  'journal',
#  'xxxiv',
#  'friend',
#  'xxxv',
#  'heartache',
#  'xxxvi',
#  'beth',
#  'secret',
#  'xxxvii',
#  'new',
#  'impression',
#  'xxxviii',
#  'shelf',
#  'xxxix',
#  'lazy',
#  'laurence',
#  'xl',
#  'valley',
#  'shadow',
#  'xli',
#  'learning',
#  'forget',
#  'xlii',
#  'alone',
#  'xliii',
#  'surprise',
#  'xliv',
#  'lord',
#  'lady',
#  'xlv',
#  'daisy',
#  'demi',
#  'xlvi',
#  'umbrella',
#  'xlvii',
#  'harvest',
#  'time',
#  'illustration',
#  'content',
#  'illustration',
#  'list',
#  'illustration',
#  'illustration',
#  'designed',
#  'frank',
#  'merrill',
#  'drawn',
#  'engraved',
#  'printed',
#  'supervision',
#  'george',
#  'andrew',
#  'page',
#  'drew',
#  'fire',
#  'mother',
#  'big',
#  'chair',
#  'beth',
#  'foot',
#  'titlepage',
#  'iii',
#  'preface',
#  'v',
#  'content',
#  'vii',
#  'content',
#  'ix',
#  'list',
#  'illustration',
#  'xi',
#  'illustration',
#  'xvi',
#  'christmas',
#  'wo',
#  'christmas',
#  'without',
#  'present',
#  'beth',
#  'put',
#  'pair',
#  'slipper',
#  'warm',
#  'used',
#  'frightened',
#  'turn',
#  'sit',
#  'big',
#  'chair',
#  'way',
#  'clasp',
#  'hand',
#  'cheerful',
#  'hopeful',
#  'letter',
#  'used',
#  'play',
#  'pilgrim',
#  'progress',
#  'one',
#  'beth',
#  'could',
#  'get',
#  'much',
#  'music',
#  'old',
#  'piano',
#  'nine',
#  'stopped',
#  'work',
#  'sung',
#  'usual',
#  'merry',
#  'christmas',
#  'procession',
#  'set',
#  'came',
#  'meg',
#  'gray',
#  'hanging',
#  'face',
#  'little',
#  'figure',
#  'cloudy',
#  'white',
#  'lover',
#  'kneeling',
#  'receive',
#  'pedro',
#  'blessing',
#  'talked',
#  'fence',
#  'eating',
#  'apple',
#  'cry',
#  'heir',
#  'redclyffe',
#  'jo',
#  'undertook',
#  'pinch',
#  'papered',
#  'lock',
#  'gardiner',
#  'greeted',
#  'face',
#  'face',
#  'laurence',
#  'boy',
#  'sat',
#  'stair',
#  'tell',
#  'party',
#  'kitten',
#  'stuck',
#  'like',
#  'burr',
#  'reach',
#  'curling',
#  'big',
#  'chair',
#  'reading',
#  'everlasting',
#  'belsham',
#  'took',
#  'ear',
#  'ear',
#  'laurence',
#  'hooked',
#  'big',
#  'fish',
#  'neighborly',
#  'laurie',
#  'opened',
#  'window',
#  'poll',
#  'tweaked',
#  'wig',
#  'putting',
#  'finger',
#  'chin',
#  'please',
#  'give',
#  'mother',
#  'sir',
#  'care',
#  'much',
#  'laurence',
#  'often',
#  'opened',
#  'study',
#  'door',
#  'put',
#  'arm',
#  'around',
#  'neck',
#  'kissed',
#  'cyclops',
#  'amy',
#  'bore',
#  'without',
#  'flinching',
#  'several',
#  'tingling',
#  'blow',
#  'know',
#  'girl',
#  'going',
#  'burnt',
#  'held',
#  'amy',
#  'arm',
#  'hockey',
#  'packing',
#  'go',
#  'abroady',
#  'trunk',
#  'meg',
#  'partner',
#  'appeared',
#  'asked',
#  'introduced',
#  'would',
#  'meg',
#  'holding',
#  'hand',
#  'march',
#  'said',
#  'pickwick',
#  'jo',
#  'threw',
#  'open',
#  'door',
#  'closet',
#  'jo',
#  'spent',
#  'morning',
#  'river',
#  'amy',
#  'sat',
#  'draw',
#  'pip',
#  'pip',
#  'miss',
#  'crocker',
#  'made',
#  'wry',
#  'face',
#  'work',
#  'like',
#  'bee',
#  'beth',
#  'amy',
#  'capped',
#  'climax',
#  'putting',
#  'nose',
#  'laurence',
#  'waving',
#  'hat',
#  'miss',
#  'jo',
#  'settle',
#  'merry',
#  'lunch',
#  'went',
#  'prancing',
#  'quiet',
#  'street',
#  'oh',
#  'rise',
#  'said',
#  'stunning',
#  'blow',
#  'big',
#  'greek',
#  'lexicon',
#  'sneezed',
#  'portuguese',
#  'walked',
#  'plank',
#  'give',
#  'rose',
#  'miss',
#  'kate',
#  'put',
#  'glass',
#  'ellen',
#  'tree',
#  'swinging',
#  'fro',
#  'hammock',
#  'rather',
#  'pretty',
#  'little',
#  'picture',
#  'waved',
#  'brake',
#  'face',
#  'see',
#  'bow',
#  'smile',
#  'jo',
#  'busy',
#  'hurrah',
#  'miss',
#  'march',
#  'jo',
#  'darted',
#  'away',
#  'jo',
#  'laid',
#  'sofa',
#  'affected',
#  'read',
#  'november',
#  'disagreeable',
#  'month',
#  'year',
#  'one',
#  'horrid',
#  'telegraph',
#  'thing',
#  'came',
#  'suddenly',
#  'upon',
#  'brooke',
#  'man',
#  'clipped',
#  'letter',
#  'rolled',
#  'away',
#  'wind',
#  'clock',
#  'respectful',
#  'hannah',
#  'mullet',
#  'stir',
#  'knew',
#  'dead',
#  'sat',
#  'beside',
#  'want',
#  'beth',
#  'fever',
#  'gently',
#  'stroking',
#  'head',
#  'mother',
#  'used',
#  'amy',
#  'polish',
#  'spoon',
#  'fat',
#  'silver',
#  'teapot',
#  'back',
#  'leg',
#  'air',
#  'choose',
#  'gravely',
#  'promenaded',
#  'fro',
#  'amy',
#  'march',
#  'would',
#  'leave',
#  'beth',
#  'side',
#  'letter',
#  'jo',
#  'mother',
#  'reading',
#  'note',
#  'get',
#  'goose',
#  'hold',
#  'tongue',
#  'cried',
#  'jo',
#  'covering',
#  'ear',
#  'stood',
#  'foot',
#  'like',
#  'lion',
#  'path',
#  'beth',
#  'soon',
#  'able',
#  'lie',
#  'study',
#  'sofa',
#  'day',
#  'jungfrau',
#  'popping',
#  'head',
#  'sat',
#  'big',
#  'chair',
#  'beth',
#  'sofa',
#  'three',
#  'close',
#  'shall',
#  'tell',
#  'bless',
#  'john',
#  'brooke',
#  'home',
#  'little',
#  'woman',
#  'dove',
#  'cote',
#  'small',
#  'watchman',
#  'rattle',
#  'first',
#  'wedding',
#  'artistic',
#  'attempt',
#  'foot',
#  'held',
#  'fast',
#  'panful',
#  'plaster',
#  'please',
#  'mine',
#  'literary',
#  'lesson',
#  'check',
#  'one',
#  'hundred',
#  'dollar',
#  'domestic',
#  'experience',
#  'felt',
#  'desperately',
#  'uncomfortable',
#  'bargain',
#  'assure',
#  'laurie',
#  'heroically',
#  'shut',
#  'eye',
#  'something',
#  'put',
#  'arm',
#  'call',
#  'took',
#  'saddle',
#  'horse',
#  'might',
#  'worse',
#  'call',
#  'aunt',
#  'march',
#  'shall',
#  'another',
#  'table',
#  'bought',
#  'bouquet',
#  'flo',
#  'ordered',
#  'every',
#  'one',
#  'kind',
#  'especially',
#  'officer',
#  'seen',
#  'imperial',
#  'family',
#  'several',
#  'time',
#  'trying',
#  'sketch',
#  'lion',
#  'head',
#  'wall',
#  'leaned',
#  'head',
#  'upon',
#  'hand',
#  'filling',
#  'price',
#  'bonnet',
#  'bonnie',
#  'dundee',
#  'amused',
#  'dropping',
#  'gingerbread',
#  'nut',
#  'seat',
#  'thou',
#  'shalt',
#  'haf',
#  'thy',
#  'bhaer',
#  'waved',
#  'hand',
#  'sock',
#  'dis',
#  'mine',
#  'effalunt',
#  'sat',
#  'upon',
#  'floor',
#  'read',
#  'looked',
#  'ate',
#  'presence',
#  'three',
#  'gentleman',
#  'select',
#  'symposium',
#  'prink',
#  'glass',
#  'coming',
#  'jo',
#  'stuffed',
#  'whole',
#  'bundle',
#  'stove',
#  'put',
#  'sister',
#  'carriage',
#  'laid',
#  'head',
#  'mossy',
#  'post',
#  'jo',
#  'ca',
#  'head',
#  'jo',
#  'lap',
#  'wind',
#  'blew',
#  'healthfully',
#  'hurried',
#  'forward',
#  'meet',
#  'flower',
#  'demi',
#  'daisy',
#  'mornin',
#  'dear',
#  'man',
#  'bonnet',
#  'sat',
#  'piping',
#  'stone',
#  'goat',
#  'skipped',
#  'laurie',
#  'threw',
#  'turf',
#  'rough',
#  'sketch',
#  'laurie',
#  'taming',
#  'horse',
#  'valley',
#  'shadow',
#  'sat',
#  'staring',
#  'bust',
#  'turning',
#  'ring',
#  'thoughtfully',
#  'upon',
#  'finger',
#  'laurie',
#  'laurie',
#  'knew',
#  'come',
#  'well',
#  'pull',
#  'together',
#  'jo',
#  'father',
#  'jo',
#  'laid',
#  'head',
#  'comfortable',
#  'cried',
#  'substantial',
#  'lifelike',
#  'ghost',
#  'leaning',
#  'tall',
#  'uncle',
#  'proceeded',
#  'toss',
#  'tousle',
#  'small',
#  'nephew',
#  'bhaer',
#  'glad',
#  'see',
#  'bhaer',
#  'sang',
#  'heartily',
#  'laurence',
#  'sitting',
#  'mother',
#  'lap',
#  'began',
#  'pace',
#  'love',
#  'evvybody',
#  'make',
#  'leg',
#  'go',
#  'dranpa',
#  'dranpa',
#  'bhaer',
#  'jo',
#  'enjoying',
#  'promenade',
#  'looking',
#  'saw',
#  'bhaer',
#  'suit',
#  'bhaer',
#  'umbrella',
#  'harvest',
#  'time',
#  'teddy',
#  'bore',
#  'charmed',
#  'life',
#  'leaving',
#  'march',
#  'daughter',
#  'festival',
#  'tree',
#  'illustration',
#  'illustration',
#  'illustration',
#  'christmas',
#  'wo',
#  'christmas',
#  'without',
#  'present',
#  'playing',
#  'pilgrim',
#  'christmas',
#  'wo',
#  'christmas',
#  'without',
#  'present',
#  'grumbled',
#  'jo',
#  'lying',
#  'rug',
#  'dreadful',
#  'poor',
#  'sighed',
#  'meg',
#  'looking',
#  'old',
#  'dress',
#  'think',
#  'fair',
#  'girl',
#  'plenty',
#  'pretty',
#  'thing',
#  'girl',
#  'nothing',
#  'added',
#  'little',
#  'amy',
#  'injured',
#  'sniff',
#  'got',
#  'father',
#  'mother',
#  'said',
#  'beth',
#  'contentedly',
#  'corner',
#  'four',
#  'young',
#  'face',
#  'firelight',
#  'shone',
#  'brightened',
#  'cheerful',
#  'word',
#  'darkened',
#  'jo',
#  'said',
#  'sadly',
#  'got',
#  ...]

# %%
rare_words = pd.Series(" ".join(df2["sentence"]).split()).value_counts()
rare_words
# Out:
# jo              1414
# one              939
# said             841
# little           770
# meg              704
#                 ...
# carelessness       1
# threaten           1
# ubiquitous         1
# chattering         1
# newsletter         1
# Length: 9359, dtype: int64

# %%
rare_words = rare_words[rare_words <= 2]

# %%
rare_words
# Out:
# rouser        2
# austrian      2
# catholic      2
# ho            2
# charitable    2
#              ..
# whatnot       1
# ow            1
# tranquilly    1
# missis        1
# newsletter    1
# Length: 5172, dtype: int64

# %%
rare_words.index
# Out:
# Index(['rouser', 'austrian', 'catholic', 'ho', 'charitable', 'wanderer',
#        'dashed', 'resume', 'pious', 'mathematics',
#        ...
#        'buyer', 'boiler', 'exploding', 'ingenuity', 'mercury', 'whatnot', 'ow',
#        'tranquilly', 'missis', 'newsletter'],
#       dtype='object', length=5172)

# %%
df2["sentence"] = df2["sentence"].apply(lambda x: " ".join([i for i in x.split() if i not in rare_words.index]))
df2["sentence"].head()
# Out:
# 0    project gutenberg ebook little woman louisa al...
# 1
# 2                       ebook use anyone anywhere cost
# 3                            almost may copy give away
# 4              term project gutenberg license included
# Name: sentence, dtype: object

# %% [markdown]
# ## 4. WordCloud - Repetition of Words
#
# Now you'll create a Word Clouds for reviews, representing most common words in each target class.
#
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance. Significant textual data points can be highlighted using a word cloud.
#
# You are expected to create separate word clouds for positive and negative reviews. You can qualify a review as positive or negative, by looking at its recommended status. You may need to use capabilities of matplotlib for visualizations.
#
# You can follow the steps below:
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud

# %%
#https://python-course.eu/applications-python/python-wordcloud-tutorial.php

# %%
from wordcloud import WordCloud

# %%
wordcloud_words = WordCloud(background_color="white", max_words =100)

# %%
wc = WordCloud(background_color = "black", width = 1200, height = 600,
               contour_width = 0, contour_color = "#410F01", max_words = 1000,
               scale = 1, collocations = False, repeat = True, min_font_size = 1)
wc.generate(" ".join(df["sentence"].values))

plt.figure(figsize = [15, 7])
plt.title("Top Words in the Text")
plt.imshow(wc)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from PIL import Image

women_mask = np.array(Image.open("little.jpg"))
#dove_mask[230:250, 240:250]
plt.imshow(women_mask)
plt.axis("off")
plt.show()

# %%
from PIL import Image

women_mask = np.array(Image.open("büşş.jpg"))
#dove_mask[230:250, 240:250]
plt.imshow(women_mask)
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="black", 
                      mask=women_mask,
                      contour_width=3, 
                      repeat=True,
                      min_font_size=3,
                      contour_color='darkgreen')

# Generate a wordcloud
wordcloud.generate(" ".join(df["sentence"].values))

# store to file
wordcloud.to_file("büşş.jpg")

# show

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from PIL import Image

women_mask = np.array(Image.open("son.jpg"))
#dove_mask[230:250, 240:250]
plt.imshow(women_mask)
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white", 
                      mask=women_mask,
                      contour_width=5, 
                      repeat=True,
                      min_font_size=1,
                      contour_color='darkgreen')

# Generate a wordcloud
wordcloud.generate(" ".join(df["sentence"].values))

# store to file
wordcloud.to_file("son.jpg")

# show

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from PIL import Image

women_mask = np.array(Image.open("büşş.jpg"))
#dove_mask[230:250, 240:250]
plt.imshow(women_mask)
plt.axis("off")
plt.show()

# %%
women_img = Image.fromarray(wordcloud.to_array())
women_mask_img = Image.fromarray(women_mask)

new_img = Image.blend(women_img, 
                      women_mask_img, 
                      0.5)
new_img.save("büşş.jpn","PNG")
plt.imshow(new_img)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize = (13,13))
plt.imshow(wordcloud_words, interpolation="bilinear",)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21756\2139038440.py in <module>
#       1 plt.figure(figsize = (13,13))
# ----> 2 plt.imshow(wordcloud_words, interpolation="bilinear",)
#       3 plt.axis("off")
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2651         resample=None, url=None, data=None, **kwargs):
# -> 2652     __ret = gca().imshow(
#    2653         X, cmap=cmap, norm=norm, aspect=aspect,
#    2654         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5479                               **kwargs)
#    5480
# -> 5481         im.set_data(X)
#    5482         im.set_alpha(alpha)
#    5483         if im.get_clip_path() is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     700         if isinstance(A, PIL.Image.Image):
#     701             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 702         self._A = cbook.safe_masked_invalid(A, copy=True)
#     703
#     704         if (self._A.dtype != np.uint8 and
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     699
#     700 def safe_masked_invalid(x, copy=False):
# --> 701     x = np.array(x, subok=True, copy=copy)
#     702     if not x.dtype.isnative:
#     703         # If we have already made a copy, do the byteswap in place, else make a
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in __array__(self)
#     745             Word cloud image as numpy matrix.
#     746         """
# --> 747         return self.to_array()
#     748
#     749     def to_svg(self, embed_font=False, optimize_embedded_font=True, embed_image=False):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in to_array(self)
#     735             Word cloud image as numpy matrix.
#     736         """
# --> 737         return np.array(self.to_image())
#     738
#     739     def __array__(self):
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in to_image(self)
#     646
#     647     def to_image(self):
# --> 648         self._check_generated()
#     649         if self.mask is not None:
#     650             width = self.mask.shape[1]
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in _check_generated(self)
#     642         """Check if ``layout_`` was computed, otherwise raise error."""
#     643         if not hasattr(self, "layout_"):
# --> 644             raise ValueError("WordCloud has not been calculated, call generate"
#     645                              " first.")
#     646
#
# ValueError: WordCloud has not been calculated, call generate first.

# %%
word_tokenize(df.sentence[15])
#bütün kelimeleri birer token haline getiriyor
# Out:
# ['release', 'date', 'august', 'ebook']

# %%
corpus = []
for i in df.sentence:
    corpus.append(word_tokenize(i))
print(corpus[:100])

# word2vec algoritması tüm corpusun 2 boyutlu olmasını ister. Bu sebeple burdaki for döngüsü ile tüm documnetleri/satırları
# teker teker çekip word tokenlerine ayırıyoruz. Word_tokenize fonksiyonu default olarak texti word tokenlerine ayırıp bir 
# listeye atar. Bu listeler corpus listesine append edilerek corpus 2 boyutlu hale getiritir.
# Out:
# [['project', 'gutenberg', 'ebook', 'little', 'woman', 'louisa', 'alcott'], [], ['ebook', 'use', 'anyone', 'anywhere', 'no', 'cost'], ['almost', 'no', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away'], ['term', 'project', 'gutenberg', 'license', 'included'], ['ebook', 'online'], [], [], ['title', 'little', 'woman'], ['meg', 'jo', 'beth', 'amy'], [], ['author', 'louisa', 'alcott'], [], ['illustrator', 'frank', 'merrill'], [], ['release', 'date', 'august', 'ebook'], ['last', 'update', 'august'], [], ['language', 'english'], [], [], ['start', 'project', 'gutenberg', 'ebook', 'little', 'woman'], [], [], [], [], ['produced', 'david', 'edward', 'ernest', 'schaal', 'robert', 'homa'], ['online', 'distributed', 'proofreading', 'team'], ['file', 'produced', 'image', 'generously', 'made', 'available'], ['internet', 'archive'], [], [], [], [], [], [], [], [], [], ['illustration', 'little', 'woman'], ['meg', 'jo', 'beth', 'amy'], ['louisa', 'alcott'], [], [], [], [], ['little', 'woman'], [], [], ['illustration', 'drew', 'fire', 'mother', 'big', 'chair'], ['beth', 'foot'], ['see', 'page', 'frontispiece'], [], [], [], [], ['little', 'woman'], [], ['meg', 'jo', 'beth', 'amy'], [], [], [], ['louisa', 'alcott'], [], ['author', 'little', 'men', 'girl'], ['story', 'etc'], [], [], ['illustration', 'frank', 'merrill'], ['picture', 'home', 'little', 'woman'], ['edmund'], [], [], ['boston'], ['little', 'brown', 'company'], [], [], [], [], ['entered', 'according', 'act', 'congress', 'year'], ['louisa', 'alcott'], ['clerk', 'office'], ['district', 'court', 'district', 'massachusetts'], [], [], [], ['louisa', 'alcott'], [], [], ['john', 'alcott'], [], [], ['boston'], ['alfred', 'mudge', 'son', 'printer'], [], [], [], [], ['illustration', 'preface'], []]

# %%
model = Word2Vec(corpus, vector_size=100, window=5, min_count=5, sg=1)

# %%
model.wv['amy']
# Out:
# array([-0.10923159,  0.13072467,  0.03761384,  0.08717307, -0.03792731,
#        -0.23263079,  0.16532098,  0.26308402, -0.18445441, -0.16684566,
#        -0.07355784, -0.21889633,  0.006088  ,  0.01364326,  0.05760694,
#        -0.21574578,  0.12933673, -0.2872026 , -0.11532544, -0.37491813,
#         0.10304199,  0.02878443,  0.12362453, -0.0251063 , -0.09413058,
#        -0.04234261, -0.12902471, -0.03398278, -0.14790621,  0.01293972,
#         0.12294166,  0.04743562,  0.00379382, -0.23672926,  0.02634928,
#         0.08852148,  0.04197003, -0.138138  , -0.11905968, -0.43067837,
#        -0.00852977, -0.13099797, -0.16392985,  0.11587094,  0.17266603,
#        -0.15167056, -0.14590687,  0.0330584 ,  0.07201734,  0.09236277,
#         0.00597316, -0.15295559,  0.01072504, -0.01339628, -0.03797968,
#         0.05165851,  0.09022664,  0.02552943, -0.23545365,  0.12458847,
#         0.10984664,  0.0053938 , -0.02791076, -0.0135391 , -0.2677591 ,
#         0.15718623,  0.07207749,  0.22412273, -0.20492959,  0.20602417,
#        -0.08037692,  0.22944961,  0.15283993, -0.0223933 ,  0.26497012,
#         0.05530802, -0.00919137, -0.00183777, -0.14541386, -0.05454775,
#        -0.03725044, -0.01384833, -0.19077712,  0.21860841, -0.00335897,
#         0.01089905, -0.05722718,  0.23600411,  0.1930506 ,  0.08684715,
#         0.25930303,  0.10161412,  0.05192962,  0.00751348,  0.31800485,
#         0.08906882, -0.02340598, -0.26668718,  0.09308764, -0.05451439],
#       dtype=float32)

# %%
model.wv.most_similar('amy')
# hangi tokenlerle anlamsal ilşki kurdu( topn) default 10 olduğu için 10 tanesini yazdırdı..
#aynı text içinde sıklıkla birlikte kullanılan kelimeleri getiriyor.
# Out:
# [('beth', 0.9927499890327454),
#  ('meg', 0.9925611019134521),
#  ('jo', 0.9916201829910278),
#  ('laurie', 0.9884529113769531),
#  ('spoke', 0.9841747879981995),
#  ('saw', 0.9822825193405151),
#  ('looking', 0.9813973903656006),
#  ('back', 0.9813187122344971),
#  ('laughed', 0.9809998869895935),
#  ('tone', 0.9808567762374878)]

# %%
model.wv.most_similar('laughed')
# Out:
# [('spoke', 0.9971317648887634),
#  ('smiling', 0.9965564012527466),
#  ('smiled', 0.9965027570724487),
#  ('turning', 0.9958611726760864),
#  ('threw', 0.9957404732704163),
#  ('leaned', 0.9956763982772827),
#  ('walked', 0.9956645965576172),
#  ('drew', 0.9956222176551819),
#  ('gently', 0.9954844117164612),
#  ('saw', 0.9954180717468262)]

# %%
model.wv.most_similar(positive=['öğrenme', 'doktor'], negative=['tedavi'], topn=5)
